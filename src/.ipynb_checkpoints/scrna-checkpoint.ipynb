# %%
include("StochasticGene.jl")
# Out:
# WARNING: replacing module StochasticGene.
# Main.StochasticGene

# %%
using PyPlot
using StatsKit

# %%
StochasticGene.assemble_all("/Users/carsonc/Box/scrna/Results/2021-02-06/")

# %%
p_T120_A_2=StochasticGene.residenceprob_G("/Users/carsonc/Box/scrna/Results/2021-02-06/rates_scRNA_T120_ss_AUXIN_2.csv",2);
p_T120_A_3=StochasticGene.residenceprob_G("/Users/carsonc/Box/scrna/Results/2021-02-06/rates_scRNA_T120_ss_AUXIN_3.csv",3);
p_T0_A_2=StochasticGene.residenceprob_G("/Users/carsonc/Box/scrna/Results/2021-02-06/rates_scRNA_T0_ss_AUXIN_2.csv",2);
p_T0_A_3=StochasticGene.residenceprob_G("/Users/carsonc/Box/scrna/Results/2021-02-06/rates_scRNA_T0_ss_AUXIN_3.csv",3);

# %%
p_T120_D_2=StochasticGene.residenceprob_G("/Users/carsonc/Box/scrna/Results/2021-02-06/rates_scRNA_T120_ss_DMSO_2.csv",2);
p_T120_D_3=StochasticGene.residenceprob_G("/Users/carsonc/Box/scrna/Results/2021-02-06/rates_scRNA_T120_ss_DMSO_3.csv",3);
p_T0_D_2=StochasticGene.residenceprob_G("/Users/carsonc/Box/scrna/Results/2021-02-06/rates_scRNA_T0_ss_DMSO_2.csv",2);
p_T0_D_3=StochasticGene.residenceprob_G("/Users/carsonc/Box/scrna/Results/2021-02-06/rates_scRNA_T0_ss_DMSO_3.csv",3);

# %%
r_T120_D_2 = StochasticGene.readdlm("/Users/carsonc/Box/scrna/Results/2021-02-06/rates_scRNA_T120_ss_DMSO_2.csv",',');
r_T120_D_3 = StochasticGene.readdlm("/Users/carsonc/Box/scrna/Results/2021-02-06/rates_scRNA_T120_ss_DMSO_3.csv",',');
r_T120_A_2 = StochasticGene.readdlm("/Users/carsonc/Box/scrna/Results/2021-02-06/rates_scRNA_T120_ss_AUXIN_2.csv",',');
r_T120_A_3 = StochasticGene.readdlm("/Users/carsonc/Box/scrna/Results/2021-02-06/rates_scRNA_T120_ss_AUXIN_3.csv",',');
r_0_D_2 = StochasticGene.readdlm("/Users/carsonc/Box/scrna/Results/2021-02-06/rates_scRNA_T0_ss_DMSO_2.csv",',');
r_0_D_3 = StochasticGene.readdlm("/Users/carsonc/Box/scrna/Results/2021-02-06/rates_scRNA_T0_ss_DMSO_3.csv",',');
r_0_A_2 = StochasticGene.readdlm("/Users/carsonc/Box/scrna/Results/2021-02-06/rates_scRNA_T0_ss_AUXIN_2.csv",',');
r_0_A_3 = StochasticGene.readdlm("/Users/carsonc/Box/scrna/Results/2021-02-06/rates_scRNA_T0_ss_AUXIN_3.csv",',');

# %%
t = StochasticGene.rna_stats(r_T120_D_3[:,1],["DMSO","AUXIN"]);

# %%
plot(data_p120_3.T,data_p120_3.RG1,".")
plot(data_p120_3.T,MultivariateStats.predict(ols))
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7fb98a3b4400>

# %%
hist(t)
mean(t)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 0.004243161305680157

# %%
data_p120_3 = DataFrame(Gene = p_T120_D_3[:,1],T=t, RG1=log.(p_T120_D_3[:,2])-log.(p_T120_A_3[:,2]), RG2=log.(p_T120_D_3[:,3])-log.(p_T120_A_3[:,3]), RG3=log.(p_T120_D_3[:,4])-log.(p_T120_A_3[:,4]));

# %%
ols = lm(@formula(RG1 ~ T), data_p120_3)
# Out:
# StatsModels.TableRegressionModel{LinearModel{GLM.LmResp{Array{Float64,1}},GLM.DensePredChol{Float64,LinearAlgebra.Cholesky{Float64,Array{Float64,2}}}},Array{Float64,2}}
#
# RG1 ~ 1 + T
#
# Coefficients:
# ───────────────────────────────────────────────────────────────────────
#                 Coef.  Std. Error     t  Pr(>|t|)  Lower 95%  Upper 95%
# ───────────────────────────────────────────────────────────────────────
# (Intercept)  0.280841    0.531271  0.53    0.5983  -0.774309    1.33599
# T            3.16128     1.01448   3.12    0.0024   1.14643     5.17614
# ───────────────────────────────────────────────────────────────────────

# %%
StochasticGene.plot_histogram_rna("SOX9","DMSO",3,3,"scRNA_T120_ss_","Results/2021-02-06","/Users/carsonc/Box/scrna/")
StochasticGene.plot_histogram_rna("SOX9","AUXIN",3,3,"scRNA_T120_ss_","Results/2021-02-06","/Users/carsonc/Box/scrna/");
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# /Users/carsonc/Box/scrna/Results/2021-02-06/rates_scRNA_T120_ss_DMSO_SOX9_3_3.txt
# [0.014617664528290525, 0.14916176721782087, 0.1292497248184023, 0.05068201665632584, 0.9347767776253301, 0.016615139582428363, 0.09364182608492636]
# /Users/carsonc/Box/scrna/Results/2021-02-06/rates_scRNA_T120_ss_AUXIN_SOX9_3_3.txt
# [0.02576585879172839, 0.541696705976822, 0.061528169379566164, 0.6074490544133535, 5.903087574933427, 0.016615139582428363, 0.08580535548513084]
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7fb98b84f520>

# %% [markdown]
# ## StochasticGene.plot_histogram_rna("ADM","AUXIN",3,2,"scRNA_T120_ss_","Results/2021-02-06","/Users/carsonc/Box/scrna/")

# %%
data_p120_3[data_p120_3.T .> .5,:]
# Out:
# 12×5 DataFrame
# │ Row │ Gene   │ T        │ RG1         │ RG2         │ RG3        │
# │     │ Any    │ Float64  │ Float64     │ Float64     │ Float64    │
# ├─────┼────────┼──────────┼─────────────┼─────────────┼────────────┤
# │ 1   │ BDNF   │ 0.528536 │ -0.0111583  │ 0.000712177 │ 0.0104461  │
# │ 2   │ DDIT4  │ 0.565739 │ -0.189536   │ 0.145989    │ 0.0435465  │
# │ 3   │ HS3ST1 │ 0.803435 │ -0.0199577  │ -0.00737061 │ 0.0273283  │
# │ 4   │ IER5L  │ 0.754036 │ 0.474664    │ -0.477003   │ 0.0023392  │
# │ 5   │ MYC    │ 0.677826 │ -0.0633477  │ 0.00343849  │ 0.0599092  │
# │ 6   │ PLK2   │ 0.60515  │ -0.0524401  │ 0.0483377   │ 0.00410236 │
# │ 7   │ SGK223 │ 0.761638 │ -0.05803    │ 0.0264225   │ 0.0316075  │
# │ 8   │ SOCS1  │ 0.785786 │ 0.776418    │ -0.786806   │ 0.0103875  │
# │ 9   │ SOX9   │ 0.857644 │ -0.208338   │ 0.0275064   │ 0.180832   │
# │ 10  │ SRGAP1 │ 0.551784 │ -0.00304736 │ -0.102017   │ 0.105065   │
# ...

# %%
MultivariateStats.predict(ols)
# Out:
# 94-element Array{Float64,1}:
#  -0.15993593449817378
#   0.295423307123809
#   0.004177392744890374
#  -0.2528128618271835
#  -1.9029574591988603
#   0.3985251273101439
#  -0.47133945129676974
#   0.8582659272667905
#   0.45412863125018776
#  -0.24096304398490437
#   0.32869052379434704
#   0.14052418356897065
#   0.3784826315739178
#   ⋮
#   0.5738318331851224
#   0.8831696439054215
#   0.9457576373429692
#   0.7497544475500557
#   0.2568834514716364
#   0.8885280755502507
#  -0.3775499529138831
#   0.4772258767659848
#   0.40419157749049883
#  -0.7205118712774019
#   0.4799652151538035
#  -1.0340101739965875

# %%
plot(ols)
# Out:
# (in a Julia function called from Python)
# JULIA: MethodError: no method matching iterate(::StatsModels.TableRegressionModel{LinearModel{GLM.LmResp{Array{Float64,1}},GLM.DensePredChol{Float64,LinearAlgebra.Cholesky{Float64,Array{Float64,2}}}},Array{Float64,2}})
# Closest candidates are:
#   iterate(!Matched::Core.SimpleVector) at essentials.jl:603
#   iterate(!Matched::Core.SimpleVector, !Matched::Any) at essentials.jl:603
#   iterate(!Matched::ExponentialBackOff) at error.jl:253
#   ...
# Stacktrace:
#  [1] jlwrap_iterator(::StatsModels.TableRegressionModel{LinearModel{GLM.LmResp{Array{Float64,1}},GLM.DensePredChol{Float64,LinearAlgebra.Cholesky{Float64,Array{Float64,2}}}},Array{Float64,2}}) at /Users/carsonc/.julia/packages/PyCall/tqyST/src/pyiterator.jl:144
#  [2] pyjlwrap_getiter(::Ptr{PyCall.PyObject_struct}) at /Users/carsonc/.julia/packages/PyCall/tqyST/src/pyiterator.jl:125
#  [3] macro expansion at /Users/carsonc/.julia/packages/PyCall/tqyST/src/exception.jl:95 [inlined]
# ...
